-- %%
-- Table   t_cardinality
-- --------------------------
INSERT INTO t_cardinality ([Cardinality]) VALUES (N'*');
INSERT INTO t_cardinality ([Cardinality]) VALUES (N'0');
INSERT INTO t_cardinality ([Cardinality]) VALUES (N'0..*');
INSERT INTO t_cardinality ([Cardinality]) VALUES (N'0..1');
INSERT INTO t_cardinality ([Cardinality]) VALUES (N'1');
INSERT INTO t_cardinality ([Cardinality]) VALUES (N'1..');
INSERT INTO t_cardinality ([Cardinality]) VALUES (N'1..*');


-- Table   t_complexitytypes
-- --------------------------
INSERT INTO t_complexitytypes ([Complexity],[NumericWeight]) VALUES (N'Extreme',6);
INSERT INTO t_complexitytypes ([Complexity],[NumericWeight]) VALUES (N'High',4);
INSERT INTO t_complexitytypes ([Complexity],[NumericWeight]) VALUES (N'Low',2);
INSERT INTO t_complexitytypes ([Complexity],[NumericWeight]) VALUES (N'Medium',3);
INSERT INTO t_complexitytypes ([Complexity],[NumericWeight]) VALUES (N'V.High',5);
INSERT INTO t_complexitytypes ([Complexity],[NumericWeight]) VALUES (N'V.Low',1);
