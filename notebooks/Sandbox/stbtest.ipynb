# %%
import os
project_root = os.path.abspath('../..')

import sys
sys.path.append(project_root + '/pythonWork/pythonSource')
sys.path.append(project_root + '/pythonWork/pythonSource/IM_db')

from SSOT_db.IM_JSON import JSModel
from LOAD_MODELS.LOAD_DATASPOT import DSAccess,DSTenant
import logging

# %%
fyaycrepo = 'https://partner.dataspot.io'
fyaycrepodb = "foryouandyourcustomers"
fyayctenantname = "foryouandyourcustomers"
dstenantname = "Basis - Schwipsti GmbH"
bossardtenantname="Bossard"
bossardDS = "/Users/stb/Documents/Projekte/Bossard/dataspot"
dsaccess = DSAccess(repository=fyaycrepo, repoowner=fyaycrepodb,
                                           tenantname=dstenantname, viaazure=True)
tenant = DSTenant(lang="de", dsaccess=dsaccess)
logging.warning("finished")
# Out:
# WARNING:root:duplicate domain-name "Jahr" in model "Datentypen".  Prefixed with "Datentypen"
# WARNING:root:duplicate domain-name "BOOL" in model "Personaldatenbank".  Prefixed with "Personaldatenbank"
# WARNING:root:duplicate domain-name "DATE" in model "Personaldatenbank".  Prefixed with "Personaldatenbank"
# WARNING:root:duplicate domain-name "DEC" in model "Personaldatenbank".  Prefixed with "Personaldatenbank"
# WARNING:root:duplicate domain-name "EMPL_NO" in model "Personaldatenbank".  Prefixed with "Personaldatenbank"
# WARNING:root:duplicate domain-name "INT" in model "Personaldatenbank".  Prefixed with "Personaldatenbank"
# WARNING:root:duplicate domain-name "TIMESTAMP" in model "Personaldatenbank".  Prefixed with "Personaldatenbank"
# WARNING:root:duplicate domain-name "VARCHAR" in model "Personaldatenbank".  Prefixed with "Personaldatenbank"
# WARNING:root:duplicate domain-name "INT" in model "CRM".  Prefixed with "CRM"
# WARNING:root:duplicate domain-name "BOOL" in model "CRM".  Prefixed with "CRM"
# WARNING:root:duplicate domain-name "DATE" in model "CRM".  Prefixed with "CRM"
# WARNING:root:duplicate domain-name "DEC" in model "CRM".  Prefixed with "CRM"
# WARNING:root:duplicate domain-name "TIMESTAMP" in model "CRM".  Prefixed with "CRM"
# WARNING:root:duplicate domain-name "VARCHAR" in model "CRM".  Prefixed with "CRM"
# WARNING:root:duplicate domain-name "INT" in model "Einkaufsdatenbank".  Prefixed with "Einkaufsdatenbank"
# WARNING:root:duplicate domain-name "BOOL" in model "Einkaufsdatenbank".  Prefixed with "Einkaufsdatenbank"
# WARNING:root:duplicate domain-name "DATE" in model "Einkaufsdatenbank".  Prefixed with "Einkaufsdatenbank"
# WARNING:root:duplicate domain-name "DEC" in model "Einkaufsdatenbank".  Prefixed with "Einkaufsdatenbank"
# WARNING:root:duplicate domain-name "TIMESTAMP" in model "Einkaufsdatenbank".  Prefixed with "Einkaufsdatenbank"
# WARNING:root:duplicate domain-name "VARCHAR" in model "Einkaufsdatenbank".  Prefixed with "Einkaufsdatenbank"
# WARNING:root:duplicate domain-name "BOOL" in model "Finanzdatenbank".  Prefixed with "Finanzdatenbank"
# WARNING:root:duplicate domain-name "DATE" in model "Finanzdatenbank".  Prefixed with "Finanzdatenbank"
# WARNING:root:duplicate domain-name "DEC" in model "Finanzdatenbank".  Prefixed with "Finanzdatenbank"
# WARNING:root:duplicate domain-name "INT" in model "Finanzdatenbank".  Prefixed with "Finanzdatenbank"
# WARNING:root:duplicate domain-name "TIMESTAMP" in model "Finanzdatenbank".  Prefixed with "Finanzdatenbank"
# WARNING:root:duplicate domain-name "VARCHAR" in model "Finanzdatenbank".  Prefixed with "Finanzdatenbank"
# WARNING:root:duplicate domain-name "BOOL" in model "Personaldatenbank".  Prefixed with "Personaldatenbank"
# WARNING:root:duplicate domain-name "DATE" in model "Personaldatenbank".  Prefixed with "Personaldatenbank"
# WARNING:root:duplicate domain-name "DEC" in model "Personaldatenbank".  Prefixed with "Personaldatenbank"
# WARNING:root:duplicate domain-name "INT" in model "Personaldatenbank".  Prefixed with "Personaldatenbank"
# WARNING:root:duplicate domain-name "TIMESTAMP" in model "Personaldatenbank".  Prefixed with "Personaldatenbank"
# WARNING:root:duplicate domain-name "VARCHAR" in model "Personaldatenbank".  Prefixed with "Personaldatenbank"
# WARNING:root:duplicate domain-name "BOOL" in model "Vertriebsdatenbank".  Prefixed with "Vertriebsdatenbank"
# WARNING:root:duplicate domain-name "DATE" in model "Vertriebsdatenbank".  Prefixed with "Vertriebsdatenbank"
# WARNING:root:duplicate domain-name "DEC" in model "Vertriebsdatenbank".  Prefixed with "Vertriebsdatenbank"
# WARNING:root:duplicate domain-name "INT" in model "Vertriebsdatenbank".  Prefixed with "Vertriebsdatenbank"
# WARNING:root:duplicate domain-name "TIMESTAMP" in model "Vertriebsdatenbank".  Prefixed with "Vertriebsdatenbank"
# WARNING:root:duplicate domain-name "VARCHAR" in model "Vertriebsdatenbank".  Prefixed with "Vertriebsdatenbank"
# WARNING:root:duplicate domain-name "EMPL_NO" in model "Personaldatenbank".  Prefixed with "Personaldatenbank"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-ca541c78f509> in <module>
#       7 dsaccess = DSAccess(repository=fyaycrepo, repoowner=fyaycrepodb,
#       8                                            tenantname=dstenantname, viaazure=True)
# ----> 9 tenant = DSTenant(lang="de", dsaccess=dsaccess)
#      10 print ("finished")
#
# ~/Documents/Projekte/SPODtools/pythonWork/pythonSource/LOAD_MODELS/LOAD_DATASPOT/dstenant.py in __init__(self, lang, tenantname, dsaccess)
#      46         self._getattributes()
#      47         self._gettables()
# ---> 48         self._getcolumns()
#      49         self._fillarcs()
#      50         self._getrules()
#
# ~/Documents/Projekte/SPODtools/pythonWork/pythonSource/LOAD_MODELS/LOAD_DATASPOT/dstenant.py in _getcolumns(self)
#     362             self._columns = []
#     363         else:
# --> 364             dscols = self._dsaccess.getcolumns()
#     365             self._columns = [DSColumn(col=col, tenant=self) for col in dscols]
#     366             self._udps.append(DSColumn.udptypes(cols=self._columns))
#
# ~/Documents/Projekte/SPODtools/pythonWork/pythonSource/LOAD_MODELS/LOAD_DATASPOT/dsrequests.py in getcolumns(self, modelid)
#     325
#     326     def getcolumns(self, modelid=None):
# --> 327         cols = self._getelements(elemtype="attributes",
#     328                                  filtercondition=lambda elem: (modelid is None or elem.get("modelId") == modelid) and
#     329                                                               elem.get("_type") == self.UmlAttribute)
#
# ~/Documents/Projekte/SPODtools/pythonWork/pythonSource/LOAD_MODELS/LOAD_DATASPOT/dsrequests.py in _getelements(self, elemtype, subtypes, filtercondition)
#     198     def _getelements(self, elemtype, subtypes: list = None,
#     199                      filtercondition=lambda x: True):
# --> 200         answer = self._doget(request=f"/{elemtype}/")
#     201         if "_embedded" in answer:
#     202             elems = answer["_embedded"][elemtype]
#
# ~/Documents/Projekte/SPODtools/pythonWork/pythonSource/LOAD_MODELS/LOAD_DATASPOT/dsrequests.py in _doget(self, request)
#      72     def _doget(self, request):
#      73         locrequest = self._basehttprequest() + request
# ---> 74         response = req.get(locrequest, auth=self._auth, headers=self._buildheader())
#      75         if response.status_code != 200:
#      76             raise Exception(f"api access error {response.text}")
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     683
#     684         if not stream:
# --> 685             r.content
#     686
#     687         return r
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/models.py in content(self)
#     827                 self._content = None
#     828             else:
# --> 829                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     830
#     831         self._content_consumed = True
#
# /usr/local/anaconda3/lib/python3.8/site-packages/requests/models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     569         """
#     570         if self.chunked and self.supports_chunked_reads():
# --> 571             for line in self.read_chunked(amt, decode_content=decode_content):
#     572                 yield line
#     573         else:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     761
#     762             while True:
# --> 763                 self._update_chunk_length()
#     764                 if self.chunk_left == 0:
#     765                     break
#
# /usr/local/anaconda3/lib/python3.8/site-packages/urllib3/response.py in _update_chunk_length(self)
#     691         if self.chunk_left is not None:
#     692             return
# --> 693         line = self._fp.fp.readline()
#     694         line = line.split(b";", 1)[0]
#     695         try:
#
# /usr/local/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /usr/local/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /usr/local/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
readjson = JSModel(pmodel=tenant.spodjson(),pwithversioncheck=False)
readjson.write_json(bossardDS+ "/bossarddataspot.json")
#createJSON.createJSON(pfilepath=bossardDS, pfilename="bossard.json")
logging.warning("finished2")
