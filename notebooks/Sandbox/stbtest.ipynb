# %%
import os
project_root = os.path.abspath('../..')

import sys
sys.path.append(project_root + '/pythonWork/pythonSource')
sys.path.append(project_root + '/pythonWork/pythonSource/IM_db')

from IM_ODM import createJSON
from IM_DB import parameters

param1 = project_root + '/pythonWork/testModels/crmTest/crmTest.params'
parameters.initparam(p_callarg=param1)
filename = parameters.odmModelName()
filepath = parameters.dbDirect()
createJSON.createJSON(pfilepath=filepath, pfilename=filename)
print (filepath+filename+" created")
