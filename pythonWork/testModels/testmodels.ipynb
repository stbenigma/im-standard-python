# %%
from IM_ODM import fillDB
fillDB.main("/Users/stb/Documents/Projekte/FYAYC_intern/fyyccim-tools/pythonWork/testModels/testmodell-1")
# Out:
# /Users/stb/Documents/Projekte/FYAYC_intern/fyyccim-tools/pythonWork/testModels/testmodell-1
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-5c073f05a49a> in <module>
#       1 from IM_ODM import fillDB
# ----> 2 fillDB.main("/Users/stb/Documents/Projekte/FYAYC_intern/fyyccim-tools/pythonWork/testModels/testmodell-1")
#
# ~/Documents/Projekte/FYAYC_intern/fyyccim-tools/pythonWork/pythonSource/IM_ODM/fillDB.py in main(p_param1)
#      49 def main(p_param1):
#      50     """Main program for fillDB"""
# ---> 51     parameters.initparam(p_callarg=p_param1)
#      52     logmessages.initlog('fillDB')
#      53
#
# ~/Documents/Projekte/FYAYC_intern/fyyccim-tools/pythonWork/pythonSource/IM_db/IM_DB/parameters.py in initparam(p_callarg, pfileonly)
#     539             raise Exception("parameter is no file")
#     540         else:
# ...
